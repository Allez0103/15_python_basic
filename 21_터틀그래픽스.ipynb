# %%
import turtle as t

t.shape('turtle')

# %%
t.forward(100)

# %%
t.right(90)

# %%
t.forward(100)

# %%
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)

# %%
for i in range(4):
    t.fd(100)
    t.rt(90)

# %%
t.clear()

# %%
for i in range(5):
    t.fd(200)
    t.rt(72)

# %%
t.clear()

for i in range(6):
    t.fd(200)
    t.rt(60)

# %%
t.clear()

num = int(input())

for i in range(num):
    t.fd(200)
    t.rt(360/num)

# %%
t.clear()

# %%
num = int(input())

t.color('red')
t.begin_fill()
for i in range(num):
    t.fd(100)
    t.rt(360/num)
t.end_fill()
t.color('black')

# %%
t.clear()

t.circle(120)

# %%
t.clear()

n = 60
t.speed('fastest')
for i in range(n):
    t.circle(120)
    t.rt(360/n)

# %%
t.clear()

t.speed('fastest')
for i in range(300):
    t.fd(i)
    t.rt(91)
