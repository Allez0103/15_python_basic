# %%
start, stop = list(map(int, input().split()))

num = [i for i in range(start, stop + 1) if i % 10 != 3 and i % 10 != 7]
for j in num:
    # print(num[j - 1])
    pass

# %%
###

# %%
import random
names = [
    "권석현", "김규원", "김성준", "김태훈", "김형민", "문홍식", "박규민", "박성민", "박진영", "박찬현",
    "박희재", "손성욱", "신재민", "오은진", "원영배","이도영", "이수현", "이원석", "이진욱", "조현우", "홍득훈"
]
student_data = {}
for name in names:
    student_data[name] = [random.randint(0, 100) for _ in range(10)]

class student:
    def __init__(self, name, scores):
        self.name = name
        self.scores = scores
    def total(self):
        return sum(self.scores)
    def average(self):
        return self.total() / len(self.scores)
    def max_score(self):
        return max(self.scores)
    def min_score(self):
        return min(self.scores)
    def is_pass(self):
        if self.average() > 70:
            return "합격"
        else:
            return "불합격"
    def print_info(self):
        print(f"이름: {self.name}")
        print(f"총점: {self.total()}")
        print(f"평균: {self.average()}")
        print(f"최고점: {self.max_score()}")
        print(f"최저점: {self.min_score()}")
        print(f"{self.is_pass()}")

for i in names:
    globals()[i] = student(i, student_data[i])

조현우.print_info()
이진욱.print_info()
문홍식.average()
# Out:
# 이름: 조현우
# 총점: 600
# 평균: 60.0
# 최고점: 99
# 최저점: 0
# 불합격
# 이름: 이진욱
# 총점: 340
# 평균: 34.0
# 최고점: 97
# 최저점: 2
# 불합격
# 51.2

# %%
###
