# %%
## 클래스 상속

# 기반클래스(부모클래스)와 파생클래스(자식클래스)

# class 기반클래스:
#     수행할코드
# class 파생클래스(기반클래스):
#     수행할코드

# %%
# 사람클래스로 학생클래스 만들기

class Person:
    def greeting(self):
        print('안녕하세요.')

class Student(Person):
    def study(self):
        print('공부하기')

james = Student()
james.greeting()
james.study()
# Out:
# 안녕하세요.
# 공부하기

# %%
issubclass(Student, Person)
issubclass(Person, Student)
# Out:
# False

# %%
# 상속관계

class Person:
    def greeting(self):
        print('안녕하세요.')

class Student(Person):
    def study(self):
        print('공부하기')

# %%
# 포함관계

class Person:
    def greeting(self):
        print('안녕하세요.')

class PersonList:
    def __init__(self):
        self.person_list = []
    
    def append_person(self, person):
        self.person_list.append(person)

# %%
lists = PersonList()
james = Person()
maria = Person()

lists.append_person(james)

# %%
# 기반클래스의 속성 사용하기

class Person:
    def __init__(self):
        print("Person __init__")
        self.hello = '안녕하세요.'

class Student(Person):
    def __init__(self):
        print("Student __init__")
        self.school = '파이썬 코딩 도장'

james = Student()
# 기반 클래스의 init은 출력되지 않는다.

print(james.school)
# print(james.hello)
# 기반클래스의 변수는 출력이 안된다
# Out:
# Student __init__
# 파이썬 코딩 도장

# %%
# super 로 기반 클래스 초기화하기

class Person:
    def __init__(self):
        print("Person __init__")
        self.hello = '안녕하세요.'

class Student(Person):
    def __init__(self):
        print("Student __init__")
        super().__init__()
        self.school = '파이썬 코딩 도장'

james = Student()
# 기반 클래스의 init 출력

print(james.school)
print(james.hello)
# 기반클래스의 변수 출력가능
# Out:
# Student __init__
# Person __init__
# 파이썬 코딩 도장
# 안녕하세요.

# %%
# 기반 클래스를 초기화하지 않아도 되는 경우

class Person:
    def __init__(self):
        print("Person __init__")
        self.hello = '안녕하세요.'


class Student(Person):
    pass
# __init__ 을 오버라이딩 하지 않음

james = Student()
print(james.hello)
# Out:
# Person __init__
# 안녕하세요.

# %%
# 메서드 오버라이딩

class Person:
    def greeting(self):
        print('안녕하세요')


class Student(Person):
    def greeting(self):
        print('안녕하세요. 저는 파이썬 학생입니다.')

james = Student()
james.greeting()
# Out:
# 안녕하세요. 저는 파이썬 학생입니다.

# %%
class Person:
    def greeting(self):
        print('안녕하세요')


class Student(Person):
    def greeting(self):
        super().greeting()
        print('안녕하세요. 저는 파이썬 학생입니다.')

james = Student()
james.greeting()
# Out:
# 안녕하세요
# 안녕하세요. 저는 파이썬 학생입니다.

# %%
# 다중상속 사용하기

# class 기반클래스1:
#     코드

# class 기반클래스2:
#     코드

# class 파생클래스(기반클래스1, 기반클래스2):
#     코드


class Person:
    def greeting(self):
        print('안녕하세요')


class University:
    def manage_credit(self):
        print('학생관리')


class UnderGraduate(Person, University):
    def study(self):
        print('공부하기')


james = UnderGraduate()
james.greeting()
james.manage_credit()
james.study()
# Out:
# 안녕하세요
# 학생관리
# 공부하기

# %%
# 다이아몬드 상속

class A:
    def greeting(self):
        print("안녕하세요. A 입니다.")


class B(A):
    def greeting(self):
        print("안녕하세요. B 입니다.")


class C(A):
    def greeting(self):
        print("안녕하세요. C 입니다.")


class D(B, C):
    pass


x = D()
x.greeting()
D.mro()
# Out:
# 안녕하세요. B 입니다.
# [__main__.D, __main__.B, __main__.C, __main__.A, object]

# %%
# 추상 클래스 사용하기

# from abc import *       # 모든 함수 가져오기

# class 추상클래스이름(metaclass = ABCMeta):
#     @abstractmethod
#     def 매서드이름(self):
#         수행할코드


from abc import *

class StudentBase(metaclass = ABCMeta):

    @abstractmethod
    def study(self):
        pass
    
    @abstractmethod
    def go_to_school(self):
        pass


class Student(StudentBase):
    def study(self):
        print('공부하기')


# james = Student()
# james.study()
# 추상메서드의 go_to_school이 구현되지 않음

# %%
from abc import *

class StudentBase(metaclass = ABCMeta):

    @abstractmethod
    def study(self):
        pass
    
    @abstractmethod
    def go_to_school(self):
        pass


class Student(StudentBase):
    def study(self):
        print('공부하기')

    def go_to_school(self):
        print('학교가기')


james = Student()
james.study()
james.go_to_school()
# Out:
# 공부하기
# 학교가기

# %%
# 추상메서드를 빈 메서드로 만드는 이유

# james = StudentBase()

# %%
class Animal:
    def eat(self):
        print('먹다')


class Wing:
    def flap(self):
        print('파닥거리다')


class Bird(Animal, Wing):
    def fly(self):
        print('날다')


b = Bird()
b.eat()
b.flap()
b.fly()
# Out:
# 먹다
# 파닥거리다
# 날다
